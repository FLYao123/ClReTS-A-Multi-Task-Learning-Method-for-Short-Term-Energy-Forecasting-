# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, Subset
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import random
import os

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'
    torch.use_deterministic_algorithms(True)

def load_data_new(seed):
    X_data_train = pd.read_csv('/content/drive/MyDrive/CaReTS/prs_HWM_train.csv')
    Y_data_train = X_data_train

    X_train_full = X_data_train.iloc[:, 0:15].values
    y_train_full = Y_data_train.iloc[:, 15:21].values

    X_train_time = X_train_full[:, :3].astype(np.float32)
    X_train_seq = X_train_full[:, 3:].astype(np.float32)

    X_train_time[:, 0] /= 23.0
    X_train_time[:, 1] /= 7.0
    X_train_time[:, 2] /= 12.0

    X_seq_min, X_seq_max = X_train_seq.min(axis=0), X_train_seq.max(axis=0)
    y_min, y_max = y_train_full.min(axis=0), y_train_full.max(axis=0)

    X_train_seq_scaled = (X_train_seq - X_seq_min) / (X_seq_max - X_seq_min + 1e-8)
    y_train_scaled = (y_train_full - y_min) / (y_max - y_min + 1e-8)

    X_train_combined = np.concatenate([X_train_time, X_train_seq_scaled], axis=1)

    trend_labels = (y_train_full > X_train_seq[:, -1].reshape(-1, 1)).astype(int)

    X_train_tensor = torch.tensor(X_train_combined, dtype=torch.float32).unsqueeze(-1)
    y_train_tensor = torch.tensor(y_train_scaled, dtype=torch.float32)
    trend_tensor = torch.tensor(trend_labels, dtype=torch.long)

    dataset = TensorDataset(X_train_tensor, y_train_tensor, trend_tensor)

    # test set
    X_data_test = pd.read_csv('/content/drive/MyDrive/CaReTS/prs_HWM_test.csv')
    Y_data_test = X_data_test

    X_test_full = X_data_test.iloc[:, 0:15].values
    y_test_full = Y_data_test.iloc[:, 15:21].values

    X_test_time = X_test_full[:, :3].astype(np.float32)
    X_test_seq = X_test_full[:, 3:].astype(np.float32)

    X_test_time[:, 0] /= 23.0
    X_test_time[:, 1] /= 7.0
    X_test_time[:, 2] /= 12.0

    X_test_seq_scaled = (X_test_seq - X_seq_min) / (X_seq_max - X_seq_min + 1e-8)
    y_test_scaled = (y_test_full - y_min) / (y_max - y_min + 1e-8)

    X_test_combined = np.concatenate([X_test_time, X_test_seq_scaled], axis=1)

    trend_labels_test = (y_test_full > X_test_seq[:, -1].reshape(-1, 1)).astype(int)

    X_test_tensor = torch.tensor(X_test_combined, dtype=torch.float32).unsqueeze(-1)
    y_test_tensor = torch.tensor(y_test_scaled, dtype=torch.float32)
    trend_test_tensor = torch.tensor(trend_labels_test, dtype=torch.long)

    test_dataset = TensorDataset(X_test_tensor, y_test_tensor, trend_test_tensor)

    return dataset, test_dataset, (X_seq_min, X_seq_max, y_min, y_max)


class RegressionDualBranchModel(nn.Module):
    # def __init__(self, input_dim=1, hidden_dim=64, num_layers=2, output_len=6, model_type='LSTM'):
    def __init__(self, input_dim=1, hidden_dim=64, num_layers=2, output_len=6, model_type='CNN'):
    # def __init__(self, input_dim=1, hidden_dim=64, num_layers=2, output_len=6, model_type='TRANSFORMER'):
        super().__init__()
        self.output_len = output_len
        self.model_type = model_type.upper()

        if self.model_type == 'LSTM':
            self.feature_extractor = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)

        elif self.model_type == 'CNN':
            # hidden_dim
            self.feature_extractor = nn.Sequential(
                nn.Conv1d(in_channels=input_dim, out_channels=32, kernel_size=3, padding=1),
                nn.ReLU(),
                nn.Conv1d(32, hidden_dim, kernel_size=3, padding=1),
                nn.ReLU(),
                nn.AdaptiveAvgPool1d(1)  # Output shape：[B, hidden_dim, 1]
            )

        elif self.model_type == 'TRANSFORMER':

            self.input_projection = nn.Linear(input_dim, hidden_dim)

            self.pos_embedding = nn.Parameter(torch.randn(1, 25, hidden_dim))  # Maximum sequence length

            encoder_layer = nn.TransformerEncoderLayer(d_model=hidden_dim, nhead=4, batch_first=True)
            self.feature_extractor = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        else:
            raise ValueError(f"Unknown type: {self.model_type}")

        self.branch1 = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU()
        )
        self.branch2 = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU()
        )

        self.fusion = nn.Linear(2 * hidden_dim, output_len)

    def forward(self, x):
        # x: [batch, seq_len, input_dim]
        if self.model_type == 'LSTM':
            out, _ = self.feature_extractor(x)
            h = out[:, -1, :]  # [B, hidden_dim]

        elif self.model_type == 'CNN':
            # CNN expects input: [B, input_dim, seq_len]
            x_cnn = x.permute(0, 2, 1)
            out = self.feature_extractor(x_cnn)  # [B, hidden_dim, 1]
            h = out.squeeze(-1)  # [B, hidden_dim]

        elif self.model_type == 'TRANSFORMER':
            x_proj = self.input_projection(x)  # [B, seq_len, hidden_dim]
            seq_len = x_proj.size(1)
            pos_embed = self.pos_embedding[:, :seq_len, :]
            x_proj = x_proj + pos_embed
            out = self.feature_extractor(x_proj)
            h = out[:, -1, :]
        else:
            raise ValueError("Unsupported type")

        b1 = self.branch1(h)
        b2 = self.branch2(h)

        h_cat = torch.cat([b1, b2], dim=1)
        delta = self.fusion(h_cat)

        current = x[:, -1, 0].unsqueeze(1).repeat(1, self.output_len)
        y_pred = current + delta

        return y_pred


def evaluate_model(model, data_loader, y_min, y_max):
    model.eval()
    preds, trues = [], []
    with torch.no_grad():
        for X_batch, y_batch, _ in data_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            y_pred_scaled = model(X_batch)
            preds.append(y_pred_scaled.cpu().numpy())
            trues.append(y_batch.cpu().numpy())

    preds = np.vstack(preds)
    trues = np.vstack(trues)
    y_pred = preds * (y_max - y_min + 1e-8) + y_min
    y_true = trues * (y_max - y_min + 1e-8) + y_min
    mse_per_output = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    mse_total = np.mean(mse_per_output)
    rmse_total = np.sqrt(mse_total)
    return mse_per_output, mse_total, rmse_total, y_true, y_pred
# Out:
# Using device: cpu

# %%
# ==================== Main Training ====================
num_folds = 10
num_epochs = 500
batch_size = 64
base_seed = 2025

full_dataset, test_dataset, (X_min, X_max, y_min, y_max) = load_data_new(seed=base_seed)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

kf = KFold(n_splits=num_folds, shuffle=True, random_state=base_seed)

train_mse_all, val_mse_all, train_rmse_all, val_rmse_all = [], [], [], []
test_mse_per_output_all, test_mse_total_all, test_rmse_total_all = [], [], []
train_mse_per_epoch_all, val_mse_per_epoch_all = [], []


for fold_idx, (train_idx, val_idx) in enumerate(kf.split(range(len(full_dataset))), 1):
    print(f"\n=== Fold {fold_idx}/{num_folds} ===")
    set_seed(base_seed + fold_idx)

    train_subset = Subset(full_dataset, train_idx)
    val_subset = Subset(full_dataset, val_idx)

    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

    model = RegressionDualBranchModel().to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    loss_fn = nn.MSELoss()

    best_val_loss = float('inf')
    counter = 0
    patience = 50
    train_mse_per_epoch, val_mse_per_epoch = [], []

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for X_batch, y_batch, _ in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * X_batch.size(0)
        avg_train_loss = total_loss / len(train_loader.dataset)

        # Evaluation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for X_batch, y_batch, _ in val_loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                y_pred = model(X_batch)
                mse = loss_fn(y_pred, y_batch)
                val_loss += mse.item() * X_batch.size(0)
        avg_val_loss = val_loss / len(val_loader.dataset)

        train_mse_per_epoch.append(avg_train_loss)
        val_mse_per_epoch.append(avg_val_loss)

        if (epoch + 1) % 10 == 0 or epoch == 0:
            print(f"Epoch {epoch+1} | Train MSE: {avg_train_loss:.6f} | Val MSE: {avg_val_loss:.6f}")

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            counter = 0
            best_model_state = model.state_dict()
        else:
            counter += 1
            if counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    train_mse_per_epoch_all.append(train_mse_per_epoch)
    val_mse_per_epoch_all.append(val_mse_per_epoch)

    model.load_state_dict(best_model_state)

    def get_final_mse(loader):
        model.eval()
        total = 0
        with torch.no_grad():
            for X_batch, y_batch, _ in loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                pred = model(X_batch)
                mse = loss_fn(pred, y_batch)
                total += mse.item() * X_batch.size(0)
        return total / len(loader.dataset)

    train_mse = get_final_mse(train_loader)
    val_mse = get_final_mse(val_loader)
    train_rmse = np.sqrt(train_mse)
    val_rmse = np.sqrt(val_mse)

    mse_per_output, mse_total, rmse_total, y_true, y_pred = evaluate_model(model, test_loader, y_min, y_max)

    train_mse_all.append(train_mse)
    val_mse_all.append(val_mse)
    train_rmse_all.append(train_rmse)
    val_rmse_all.append(val_rmse)
    test_mse_per_output_all.append(mse_per_output)
    test_mse_total_all.append(mse_total)
    test_rmse_total_all.append(rmse_total)

    if fold_idx == num_folds:
        y_true_test_final = y_true
        y_pred_test_final = y_pred
        last_train_losses = train_mse_per_epoch
        last_val_losses = val_mse_per_epoch

    print(f"Fold {fold_idx} - Train RMSE: {train_rmse:.6f} | Val RMSE: {val_rmse:.6f} | Test RMSE: {rmse_total:.6f}")

# === Final Summary ===
print("\n=== Final Results (mean ± std over folds) ===")
print(f"Train RMSE: {np.mean(train_rmse_all):.6f} ± {np.std(train_rmse_all):.6f}")
print(f"Val   RMSE: {np.mean(val_rmse_all):.6f} ± {np.std(val_rmse_all):.6f}")
print(f"Test  RMSE: {np.mean(test_rmse_total_all):.6f} ± {np.std(test_rmse_total_all):.6f}")
# Out:
# === Fold 1/10 ===
# Epoch 1 | Train MSE: 0.016332 | Val MSE: 0.014953
# Epoch 10 | Train MSE: 0.006030 | Val MSE: 0.006042
# Epoch 20 | Train MSE: 0.004528 | Val MSE: 0.004595
# Epoch 30 | Train MSE: 0.003636 | Val MSE: 0.003558
# Epoch 40 | Train MSE: 0.003091 | Val MSE: 0.003112
# Epoch 50 | Train MSE: 0.002761 | Val MSE: 0.002824
# Epoch 60 | Train MSE: 0.002548 | Val MSE: 0.002625
# Epoch 70 | Train MSE: 0.002442 | Val MSE: 0.002651
# Epoch 80 | Train MSE: 0.002302 | Val MSE: 0.002836
# Epoch 90 | Train MSE: 0.002079 | Val MSE: 0.002424
# Epoch 100 | Train MSE: 0.002046 | Val MSE: 0.002238
# Epoch 110 | Train MSE: 0.001936 | Val MSE: 0.002148
# Epoch 120 | Train MSE: 0.001796 | Val MSE: 0.002139
# Epoch 130 | Train MSE: 0.001759 | Val MSE: 0.002119
# Epoch 140 | Train MSE: 0.001773 | Val MSE: 0.002033
# Epoch 150 | Train MSE: 0.001675 | Val MSE: 0.002189
# Epoch 160 | Train MSE: 0.001623 | Val MSE: 0.002038
# Epoch 170 | Train MSE: 0.001702 | Val MSE: 0.002033
# Epoch 180 | Train MSE: 0.001558 | Val MSE: 0.001950
# Epoch 190 | Train MSE: 0.001524 | Val MSE: 0.001858
# Epoch 200 | Train MSE: 0.001513 | Val MSE: 0.002072
# Epoch 210 | Train MSE: 0.001443 | Val MSE: 0.002008
# Epoch 220 | Train MSE: 0.001395 | Val MSE: 0.001798
# Epoch 230 | Train MSE: 0.001399 | Val MSE: 0.001864
# Epoch 240 | Train MSE: 0.001384 | Val MSE: 0.001772
# Epoch 250 | Train MSE: 0.001306 | Val MSE: 0.001841
# Epoch 260 | Train MSE: 0.001313 | Val MSE: 0.001902
# Epoch 270 | Train MSE: 0.001249 | Val MSE: 0.001812
# Epoch 280 | Train MSE: 0.001267 | Val MSE: 0.001755
# Epoch 290 | Train MSE: 0.001234 | Val MSE: 0.001801
# Epoch 300 | Train MSE: 0.001209 | Val MSE: 0.001946
# Epoch 310 | Train MSE: 0.001196 | Val MSE: 0.001698
# Epoch 320 | Train MSE: 0.001165 | Val MSE: 0.001754
# Epoch 330 | Train MSE: 0.001123 | Val MSE: 0.001743
# Epoch 340 | Train MSE: 0.001140 | Val MSE: 0.001752
# Epoch 350 | Train MSE: 0.001146 | Val MSE: 0.001817
# Epoch 360 | Train MSE: 0.001083 | Val MSE: 0.002154
# Epoch 370 | Train MSE: 0.001056 | Val MSE: 0.001719
# Epoch 380 | Train MSE: 0.001062 | Val MSE: 0.001673
# Epoch 390 | Train MSE: 0.001069 | Val MSE: 0.001652
# Epoch 400 | Train MSE: 0.001005 | Val MSE: 0.001778
# Epoch 410 | Train MSE: 0.001013 | Val MSE: 0.001624
# Epoch 420 | Train MSE: 0.000994 | Val MSE: 0.001693
# Epoch 430 | Train MSE: 0.000961 | Val MSE: 0.001639
# Epoch 440 | Train MSE: 0.000933 | Val MSE: 0.001620
# Epoch 450 | Train MSE: 0.000963 | Val MSE: 0.001886
# Epoch 460 | Train MSE: 0.000979 | Val MSE: 0.001612
# Epoch 470 | Train MSE: 0.000937 | Val MSE: 0.001610
# Epoch 480 | Train MSE: 0.000922 | Val MSE: 0.001671
# Epoch 490 | Train MSE: 0.000933 | Val MSE: 0.001603
# Epoch 500 | Train MSE: 0.000910 | Val MSE: 0.001722
# Fold 1 - Train RMSE: 0.030243 | Val RMSE: 0.041502 | Test RMSE: 0.047927
#
# === Fold 2/10 ===
# Epoch 1 | Train MSE: 0.016741 | Val MSE: 0.014646
# Epoch 10 | Train MSE: 0.006337 | Val MSE: 0.006213
# Epoch 20 | Train MSE: 0.004447 | Val MSE: 0.004214
# Epoch 30 | Train MSE: 0.003431 | Val MSE: 0.003345
# Epoch 40 | Train MSE: 0.002957 | Val MSE: 0.003105
# Epoch 50 | Train MSE: 0.002835 | Val MSE: 0.002785
# Epoch 60 | Train MSE: 0.002492 | Val MSE: 0.002828
# Epoch 70 | Train MSE: 0.002323 | Val MSE: 0.002484
# Epoch 80 | Train MSE: 0.002313 | Val MSE: 0.002681
# Epoch 90 | Train MSE: 0.002162 | Val MSE: 0.002383
# Epoch 100 | Train MSE: 0.001963 | Val MSE: 0.002333
# Epoch 110 | Train MSE: 0.001901 | Val MSE: 0.002463
# Epoch 120 | Train MSE: 0.001885 | Val MSE: 0.002205
# Epoch 130 | Train MSE: 0.001810 | Val MSE: 0.002054
# Epoch 140 | Train MSE: 0.001770 | Val MSE: 0.001941
# Epoch 150 | Train MSE: 0.001696 | Val MSE: 0.001906
# Epoch 160 | Train MSE: 0.001614 | Val MSE: 0.001965
# Epoch 170 | Train MSE: 0.001596 | Val MSE: 0.001878
# Epoch 180 | Train MSE: 0.001587 | Val MSE: 0.001897
# Epoch 190 | Train MSE: 0.001549 | Val MSE: 0.001973
# Epoch 200 | Train MSE: 0.001500 | Val MSE: 0.001861
# Epoch 210 | Train MSE: 0.001455 | Val MSE: 0.001829
# Epoch 220 | Train MSE: 0.001450 | Val MSE: 0.001960
# Epoch 230 | Train MSE: 0.001445 | Val MSE: 0.001826
# Epoch 240 | Train MSE: 0.001373 | Val MSE: 0.001837
# Epoch 250 | Train MSE: 0.001362 | Val MSE: 0.001711
# Epoch 260 | Train MSE: 0.001348 | Val MSE: 0.001888
# Epoch 270 | Train MSE: 0.001266 | Val MSE: 0.001934
# Epoch 280 | Train MSE: 0.001248 | Val MSE: 0.001718
# Epoch 290 | Train MSE: 0.001264 | Val MSE: 0.001762
# Epoch 300 | Train MSE: 0.001277 | Val MSE: 0.001781
# Epoch 310 | Train MSE: 0.001246 | Val MSE: 0.001893
# Epoch 320 | Train MSE: 0.001198 | Val MSE: 0.001711
# Epoch 330 | Train MSE: 0.001159 | Val MSE: 0.001745
# Epoch 340 | Train MSE: 0.001189 | Val MSE: 0.001803
# Epoch 350 | Train MSE: 0.001124 | Val MSE: 0.001763
# Epoch 360 | Train MSE: 0.001184 | Val MSE: 0.001763
# Epoch 370 | Train MSE: 0.001116 | Val MSE: 0.001698
# Epoch 380 | Train MSE: 0.001086 | Val MSE: 0.001741
# Epoch 390 | Train MSE: 0.001109 | Val MSE: 0.001880
# Early stopping at epoch 390
# Fold 2 - Train RMSE: 0.034023 | Val RMSE: 0.043358 | Test RMSE: 0.048016
#
# === Fold 3/10 ===
# Epoch 1 | Train MSE: 0.015902 | Val MSE: 0.014013
# Epoch 10 | Train MSE: 0.005193 | Val MSE: 0.006190
# Epoch 20 | Train MSE: 0.003951 | Val MSE: 0.003993
# Epoch 30 | Train MSE: 0.003334 | Val MSE: 0.003563
# Epoch 40 | Train MSE: 0.002917 | Val MSE: 0.002950
# Epoch 50 | Train MSE: 0.002621 | Val MSE: 0.002519
# Epoch 60 | Train MSE: 0.002446 | Val MSE: 0.002323
# Epoch 70 | Train MSE: 0.002340 | Val MSE: 0.002242
# Epoch 80 | Train MSE: 0.002133 | Val MSE: 0.002306
# Epoch 90 | Train MSE: 0.002082 | Val MSE: 0.002174
# Epoch 100 | Train MSE: 0.001977 | Val MSE: 0.002017
# Epoch 110 | Train MSE: 0.001841 | Val MSE: 0.002110
# Epoch 120 | Train MSE: 0.001826 | Val MSE: 0.002148
# Epoch 130 | Train MSE: 0.001799 | Val MSE: 0.001963
# Epoch 140 | Train MSE: 0.001619 | Val MSE: 0.001950
# Epoch 150 | Train MSE: 0.001617 | Val MSE: 0.001792
# Epoch 160 | Train MSE: 0.001572 | Val MSE: 0.001777
# Epoch 170 | Train MSE: 0.001451 | Val MSE: 0.001725
# Epoch 180 | Train MSE: 0.001482 | Val MSE: 0.001719
# Epoch 190 | Train MSE: 0.001432 | Val MSE: 0.001705
# Epoch 200 | Train MSE: 0.001413 | Val MSE: 0.001672
# Epoch 210 | Train MSE: 0.001350 | Val MSE: 0.001696
# Epoch 220 | Train MSE: 0.001352 | Val MSE: 0.001749
# Epoch 230 | Train MSE: 0.001261 | Val MSE: 0.001766
# Epoch 240 | Train MSE: 0.001257 | Val MSE: 0.001652
# Epoch 250 | Train MSE: 0.001209 | Val MSE: 0.001736
# Epoch 260 | Train MSE: 0.001164 | Val MSE: 0.001611
# Epoch 270 | Train MSE: 0.001156 | Val MSE: 0.001571
# Epoch 280 | Train MSE: 0.001165 | Val MSE: 0.001669
# Epoch 290 | Train MSE: 0.001140 | Val MSE: 0.001584
# Epoch 300 | Train MSE: 0.001164 | Val MSE: 0.001573
# Epoch 310 | Train MSE: 0.001121 | Val MSE: 0.001925
# Epoch 320 | Train MSE: 0.001092 | Val MSE: 0.001674
# Epoch 330 | Train MSE: 0.001042 | Val MSE: 0.001704
# Epoch 340 | Train MSE: 0.001050 | Val MSE: 0.001537
# Epoch 350 | Train MSE: 0.001051 | Val MSE: 0.001659
# Epoch 360 | Train MSE: 0.001026 | Val MSE: 0.001598
# Epoch 370 | Train MSE: 0.000961 | Val MSE: 0.001683
# Epoch 380 | Train MSE: 0.000991 | Val MSE: 0.001663
# Epoch 390 | Train MSE: 0.000947 | Val MSE: 0.001606
# Epoch 400 | Train MSE: 0.000966 | Val MSE: 0.001565
# Epoch 410 | Train MSE: 0.000982 | Val MSE: 0.001527
# Epoch 420 | Train MSE: 0.000897 | Val MSE: 0.001539
# Epoch 430 | Train MSE: 0.000882 | Val MSE: 0.001494
# Epoch 440 | Train MSE: 0.000891 | Val MSE: 0.001578
# Epoch 450 | Train MSE: 0.000881 | Val MSE: 0.001565
# Epoch 460 | Train MSE: 0.000938 | Val MSE: 0.001510
# Epoch 470 | Train MSE: 0.000852 | Val MSE: 0.001493
# Epoch 480 | Train MSE: 0.000822 | Val MSE: 0.001477
# Epoch 490 | Train MSE: 0.000843 | Val MSE: 0.001534
# Epoch 500 | Train MSE: 0.000839 | Val MSE: 0.001615
# Fold 3 - Train RMSE: 0.028417 | Val RMSE: 0.040188 | Test RMSE: 0.047385
#
# === Fold 4/10 ===
# Epoch 1 | Train MSE: 0.016203 | Val MSE: 0.013566
# Epoch 10 | Train MSE: 0.005700 | Val MSE: 0.004822
# Epoch 20 | Train MSE: 0.004264 | Val MSE: 0.003887
# Epoch 30 | Train MSE: 0.003574 | Val MSE: 0.003244
# Epoch 40 | Train MSE: 0.003159 | Val MSE: 0.002957
# Epoch 50 | Train MSE: 0.002754 | Val MSE: 0.003074
# Epoch 60 | Train MSE: 0.002471 | Val MSE: 0.002419
# Epoch 70 | Train MSE: 0.002343 | Val MSE: 0.002775
# Epoch 80 | Train MSE: 0.002198 | Val MSE: 0.002130
# Epoch 90 | Train MSE: 0.002142 | Val MSE: 0.002183
# Epoch 100 | Train MSE: 0.001986 | Val MSE: 0.002526
# Epoch 110 | Train MSE: 0.001899 | Val MSE: 0.001965
# Epoch 120 | Train MSE: 0.001849 | Val MSE: 0.001877
# Epoch 130 | Train MSE: 0.001796 | Val MSE: 0.001954
# Epoch 140 | Train MSE: 0.001704 | Val MSE: 0.002091
# Epoch 150 | Train MSE: 0.001665 | Val MSE: 0.001986
# Epoch 160 | Train MSE: 0.001633 | Val MSE: 0.001791
# Epoch 170 | Train MSE: 0.001560 | Val MSE: 0.001958
# Epoch 180 | Train MSE: 0.001522 | Val MSE: 0.001719
# Epoch 190 | Train MSE: 0.001468 | Val MSE: 0.001751
# Epoch 200 | Train MSE: 0.001369 | Val MSE: 0.001794
# Epoch 210 | Train MSE: 0.001405 | Val MSE: 0.001684
# Epoch 220 | Train MSE: 0.001343 | Val MSE: 0.001718
# Epoch 230 | Train MSE: 0.001362 | Val MSE: 0.001599
# Epoch 240 | Train MSE: 0.001278 | Val MSE: 0.001640
# Epoch 250 | Train MSE: 0.001288 | Val MSE: 0.001511
# Epoch 260 | Train MSE: 0.001219 | Val MSE: 0.001563
# Epoch 270 | Train MSE: 0.001193 | Val MSE: 0.001614
# Epoch 280 | Train MSE: 0.001187 | Val MSE: 0.001628
# Epoch 290 | Train MSE: 0.001142 | Val MSE: 0.001532
# Epoch 300 | Train MSE: 0.001106 | Val MSE: 0.001596
# Epoch 310 | Train MSE: 0.001056 | Val MSE: 0.001526
# Epoch 320 | Train MSE: 0.001040 | Val MSE: 0.001557
# Epoch 330 | Train MSE: 0.001055 | Val MSE: 0.001505
# Epoch 340 | Train MSE: 0.001011 | Val MSE: 0.001433
# Epoch 350 | Train MSE: 0.001063 | Val MSE: 0.001401
# Epoch 360 | Train MSE: 0.000945 | Val MSE: 0.001503
# Epoch 370 | Train MSE: 0.000990 | Val MSE: 0.001513
# Epoch 380 | Train MSE: 0.000972 | Val MSE: 0.001512
# Epoch 390 | Train MSE: 0.001013 | Val MSE: 0.001461
# Epoch 400 | Train MSE: 0.000930 | Val MSE: 0.001578
# Epoch 410 | Train MSE: 0.000884 | Val MSE: 0.001457
# Epoch 420 | Train MSE: 0.000917 | Val MSE: 0.001500
# Epoch 430 | Train MSE: 0.000940 | Val MSE: 0.001407
# Epoch 440 | Train MSE: 0.000907 | Val MSE: 0.001682
# Epoch 450 | Train MSE: 0.000842 | Val MSE: 0.001396
# Epoch 460 | Train MSE: 0.000869 | Val MSE: 0.001435
# Epoch 470 | Train MSE: 0.000861 | Val MSE: 0.001569
# Epoch 480 | Train MSE: 0.000835 | Val MSE: 0.001402
# Epoch 490 | Train MSE: 0.000848 | Val MSE: 0.001373
# Epoch 500 | Train MSE: 0.000836 | Val MSE: 0.001388
# Fold 4 - Train RMSE: 0.028772 | Val RMSE: 0.037261 | Test RMSE: 0.049481
#
# === Fold 5/10 ===
# Epoch 1 | Train MSE: 0.016603 | Val MSE: 0.015438
# Epoch 10 | Train MSE: 0.005854 | Val MSE: 0.005931
# Epoch 20 | Train MSE: 0.004335 | Val MSE: 0.004824
# Epoch 30 | Train MSE: 0.003628 | Val MSE: 0.004039
# Epoch 40 | Train MSE: 0.003154 | Val MSE: 0.003452
# Epoch 50 | Train MSE: 0.002791 | Val MSE: 0.003402
# Epoch 60 | Train MSE: 0.002599 | Val MSE: 0.002937
# Epoch 70 | Train MSE: 0.002467 | Val MSE: 0.002803
# Epoch 80 | Train MSE: 0.002314 | Val MSE: 0.002850
# Epoch 90 | Train MSE: 0.002213 | Val MSE: 0.002794
# Epoch 100 | Train MSE: 0.002115 | Val MSE: 0.002813
# Epoch 110 | Train MSE: 0.002040 | Val MSE: 0.002511
# Epoch 120 | Train MSE: 0.001911 | Val MSE: 0.002528
# Epoch 130 | Train MSE: 0.001927 | Val MSE: 0.002571
# Epoch 140 | Train MSE: 0.001812 | Val MSE: 0.002406
# Epoch 150 | Train MSE: 0.001724 | Val MSE: 0.002323
# Epoch 160 | Train MSE: 0.001722 | Val MSE: 0.002312
# Epoch 170 | Train MSE: 0.001654 | Val MSE: 0.002338
# Epoch 180 | Train MSE: 0.001569 | Val MSE: 0.002249
# Epoch 190 | Train MSE: 0.001604 | Val MSE: 0.002204
# Epoch 200 | Train MSE: 0.001532 | Val MSE: 0.002190
# Epoch 210 | Train MSE: 0.001483 | Val MSE: 0.002104
# Epoch 220 | Train MSE: 0.001421 | Val MSE: 0.002157
# Epoch 230 | Train MSE: 0.001444 | Val MSE: 0.002092
# Epoch 240 | Train MSE: 0.001410 | Val MSE: 0.002125
# Epoch 250 | Train MSE: 0.001395 | Val MSE: 0.002077
# Epoch 260 | Train MSE: 0.001305 | Val MSE: 0.002202
# Epoch 270 | Train MSE: 0.001295 | Val MSE: 0.002194
# Epoch 280 | Train MSE: 0.001267 | Val MSE: 0.002025
# Epoch 290 | Train MSE: 0.001248 | Val MSE: 0.002145
# Epoch 300 | Train MSE: 0.001334 | Val MSE: 0.002006
# Epoch 310 | Train MSE: 0.001217 | Val MSE: 0.002157
# Epoch 320 | Train MSE: 0.001197 | Val MSE: 0.002056
# Epoch 330 | Train MSE: 0.001157 | Val MSE: 0.001965
# Epoch 340 | Train MSE: 0.001182 | Val MSE: 0.002039
# Epoch 350 | Train MSE: 0.001158 | Val MSE: 0.002006
# Epoch 360 | Train MSE: 0.001137 | Val MSE: 0.001926
# Epoch 370 | Train MSE: 0.001103 | Val MSE: 0.001963
# Epoch 380 | Train MSE: 0.001126 | Val MSE: 0.001889
# Epoch 390 | Train MSE: 0.001092 | Val MSE: 0.001903
# Epoch 400 | Train MSE: 0.001066 | Val MSE: 0.002069
# Epoch 410 | Train MSE: 0.001054 | Val MSE: 0.002116
# Epoch 420 | Train MSE: 0.001077 | Val MSE: 0.002368
# Epoch 430 | Train MSE: 0.001034 | Val MSE: 0.002040
# Epoch 440 | Train MSE: 0.001015 | Val MSE: 0.001867
# Epoch 450 | Train MSE: 0.000990 | Val MSE: 0.001824
# Epoch 460 | Train MSE: 0.000999 | Val MSE: 0.001962
# Epoch 470 | Train MSE: 0.001006 | Val MSE: 0.001821
# Epoch 480 | Train MSE: 0.000978 | Val MSE: 0.001850
# Epoch 490 | Train MSE: 0.000958 | Val MSE: 0.001816
# Epoch 500 | Train MSE: 0.000959 | Val MSE: 0.001852
# Fold 5 - Train RMSE: 0.031037 | Val RMSE: 0.043035 | Test RMSE: 0.049640
#
# === Fold 6/10 ===
# Epoch 1 | Train MSE: 0.016354 | Val MSE: 0.016626
# Epoch 10 | Train MSE: 0.005581 | Val MSE: 0.005839
# Epoch 20 | Train MSE: 0.004078 | Val MSE: 0.004096
# Epoch 30 | Train MSE: 0.003260 | Val MSE: 0.003394
# Epoch 40 | Train MSE: 0.003026 | Val MSE: 0.003311
# Epoch 50 | Train MSE: 0.002820 | Val MSE: 0.003272
# Epoch 60 | Train MSE: 0.002503 | Val MSE: 0.002771
# Epoch 70 | Train MSE: 0.002348 | Val MSE: 0.002716
# Epoch 80 | Train MSE: 0.002216 | Val MSE: 0.002707
# Epoch 90 | Train MSE: 0.002161 | Val MSE: 0.002618
# Epoch 100 | Train MSE: 0.002101 | Val MSE: 0.002313
# Epoch 110 | Train MSE: 0.001935 | Val MSE: 0.002248
# Epoch 120 | Train MSE: 0.001958 | Val MSE: 0.002295
# Epoch 130 | Train MSE: 0.001847 | Val MSE: 0.002492
# Epoch 140 | Train MSE: 0.001849 | Val MSE: 0.002218
# Epoch 150 | Train MSE: 0.001820 | Val MSE: 0.002313
# Epoch 160 | Train MSE: 0.001732 | Val MSE: 0.002185
# Epoch 170 | Train MSE: 0.001693 | Val MSE: 0.002076
# Epoch 180 | Train MSE: 0.001641 | Val MSE: 0.002029
# Epoch 190 | Train MSE: 0.001636 | Val MSE: 0.002011
# Epoch 200 | Train MSE: 0.001594 | Val MSE: 0.002007
# Epoch 210 | Train MSE: 0.001487 | Val MSE: 0.001928
# Epoch 220 | Train MSE: 0.001498 | Val MSE: 0.001896
# Epoch 230 | Train MSE: 0.001472 | Val MSE: 0.001831
# Epoch 240 | Train MSE: 0.001420 | Val MSE: 0.001845
# Epoch 250 | Train MSE: 0.001406 | Val MSE: 0.001862
# Epoch 260 | Train MSE: 0.001381 | Val MSE: 0.001871
# Epoch 270 | Train MSE: 0.001354 | Val MSE: 0.001857
# Epoch 280 | Train MSE: 0.001324 | Val MSE: 0.001919
# Epoch 290 | Train MSE: 0.001309 | Val MSE: 0.001857
# Epoch 300 | Train MSE: 0.001274 | Val MSE: 0.001764
# Epoch 310 | Train MSE: 0.001332 | Val MSE: 0.001743
# Epoch 320 | Train MSE: 0.001245 | Val MSE: 0.001841
# Epoch 330 | Train MSE: 0.001161 | Val MSE: 0.001723
# Epoch 340 | Train MSE: 0.001243 | Val MSE: 0.001801
# Epoch 350 | Train MSE: 0.001171 | Val MSE: 0.001644
# Epoch 360 | Train MSE: 0.001150 | Val MSE: 0.001863
# Epoch 370 | Train MSE: 0.001167 | Val MSE: 0.001683
# Epoch 380 | Train MSE: 0.001177 | Val MSE: 0.001718
# Epoch 390 | Train MSE: 0.001129 | Val MSE: 0.001688
# Epoch 400 | Train MSE: 0.001086 | Val MSE: 0.001751
# Epoch 410 | Train MSE: 0.001087 | Val MSE: 0.001773
# Epoch 420 | Train MSE: 0.001065 | Val MSE: 0.001669
# Epoch 430 | Train MSE: 0.001027 | Val MSE: 0.001707
# Epoch 440 | Train MSE: 0.001004 | Val MSE: 0.001680
# Epoch 450 | Train MSE: 0.001018 | Val MSE: 0.001600
# Epoch 460 | Train MSE: 0.001009 | Val MSE: 0.001634
# Epoch 470 | Train MSE: 0.001031 | Val MSE: 0.001591
# Epoch 480 | Train MSE: 0.000984 | Val MSE: 0.001622
# Epoch 490 | Train MSE: 0.001008 | Val MSE: 0.001581
# Epoch 500 | Train MSE: 0.001017 | Val MSE: 0.001695
# Fold 6 - Train RMSE: 0.030723 | Val RMSE: 0.041165 | Test RMSE: 0.050086
#
# === Fold 7/10 ===
# Epoch 1 | Train MSE: 0.016288 | Val MSE: 0.014832
# Epoch 10 | Train MSE: 0.005850 | Val MSE: 0.005494
# Epoch 20 | Train MSE: 0.004211 | Val MSE: 0.004262
# Epoch 30 | Train MSE: 0.003572 | Val MSE: 0.004049
# Epoch 40 | Train MSE: 0.003195 | Val MSE: 0.003559
# Epoch 50 | Train MSE: 0.002822 | Val MSE: 0.002863
# Epoch 60 | Train MSE: 0.002639 | Val MSE: 0.002953
# Epoch 70 | Train MSE: 0.002593 | Val MSE: 0.002631
# Epoch 80 | Train MSE: 0.002329 | Val MSE: 0.002507
# Epoch 90 | Train MSE: 0.002372 | Val MSE: 0.002335
# Epoch 100 | Train MSE: 0.002152 | Val MSE: 0.002291
# Epoch 110 | Train MSE: 0.002043 | Val MSE: 0.002129
# Epoch 120 | Train MSE: 0.002013 | Val MSE: 0.002020
# Epoch 130 | Train MSE: 0.001952 | Val MSE: 0.002245
# Epoch 140 | Train MSE: 0.001829 | Val MSE: 0.001915
# Epoch 150 | Train MSE: 0.001756 | Val MSE: 0.001964
# Epoch 160 | Train MSE: 0.001722 | Val MSE: 0.002140
# Epoch 170 | Train MSE: 0.001671 | Val MSE: 0.001810
# Epoch 180 | Train MSE: 0.001626 | Val MSE: 0.002024
# Epoch 190 | Train MSE: 0.001582 | Val MSE: 0.001821
# Epoch 200 | Train MSE: 0.001494 | Val MSE: 0.001732
# Epoch 210 | Train MSE: 0.001544 | Val MSE: 0.001679
# Epoch 220 | Train MSE: 0.001534 | Val MSE: 0.001696
# Epoch 230 | Train MSE: 0.001470 | Val MSE: 0.001670
# Epoch 240 | Train MSE: 0.001427 | Val MSE: 0.001668
# Epoch 250 | Train MSE: 0.001413 | Val MSE: 0.001668
# Epoch 260 | Train MSE: 0.001336 | Val MSE: 0.001681
# Epoch 270 | Train MSE: 0.001325 | Val MSE: 0.001709
# Epoch 280 | Train MSE: 0.001352 | Val MSE: 0.002002
# Epoch 290 | Train MSE: 0.001293 | Val MSE: 0.001615
# Epoch 300 | Train MSE: 0.001252 | Val MSE: 0.001850
# Epoch 310 | Train MSE: 0.001250 | Val MSE: 0.001684
# Epoch 320 | Train MSE: 0.001189 | Val MSE: 0.001620
# Epoch 330 | Train MSE: 0.001192 | Val MSE: 0.001557
# Epoch 340 | Train MSE: 0.001181 | Val MSE: 0.001649
# Epoch 350 | Train MSE: 0.001125 | Val MSE: 0.001710
# Epoch 360 | Train MSE: 0.001154 | Val MSE: 0.001831
# Epoch 370 | Train MSE: 0.001152 | Val MSE: 0.001610
# Epoch 380 | Train MSE: 0.001122 | Val MSE: 0.001791
# Epoch 390 | Train MSE: 0.001084 | Val MSE: 0.001604
# Epoch 400 | Train MSE: 0.001072 | Val MSE: 0.001736
# Epoch 410 | Train MSE: 0.001093 | Val MSE: 0.001697
# Epoch 420 | Train MSE: 0.001075 | Val MSE: 0.001894
# Epoch 430 | Train MSE: 0.001051 | Val MSE: 0.001721
# Epoch 440 | Train MSE: 0.001014 | Val MSE: 0.001564
# Epoch 450 | Train MSE: 0.000998 | Val MSE: 0.001550
# Epoch 460 | Train MSE: 0.001004 | Val MSE: 0.001665
# Epoch 470 | Train MSE: 0.000985 | Val MSE: 0.001856
# Epoch 480 | Train MSE: 0.000992 | Val MSE: 0.001511
# Epoch 490 | Train MSE: 0.001009 | Val MSE: 0.001673
# Epoch 500 | Train MSE: 0.000967 | Val MSE: 0.001657
# Fold 7 - Train RMSE: 0.031175 | Val RMSE: 0.040701 | Test RMSE: 0.048565
#
# === Fold 8/10 ===
# Epoch 1 | Train MSE: 0.016582 | Val MSE: 0.015621
# Epoch 10 | Train MSE: 0.005890 | Val MSE: 0.005302
# Epoch 20 | Train MSE: 0.004356 | Val MSE: 0.004476
# Epoch 30 | Train MSE: 0.003454 | Val MSE: 0.003714
# Epoch 40 | Train MSE: 0.003168 | Val MSE: 0.003413
# Epoch 50 | Train MSE: 0.002845 | Val MSE: 0.003081
# Epoch 60 | Train MSE: 0.002465 | Val MSE: 0.002776
# Epoch 70 | Train MSE: 0.002310 | Val MSE: 0.002594
# Epoch 80 | Train MSE: 0.002246 | Val MSE: 0.002572
# Epoch 90 | Train MSE: 0.002158 | Val MSE: 0.002526
# Epoch 100 | Train MSE: 0.002065 | Val MSE: 0.002438
# Epoch 110 | Train MSE: 0.001960 | Val MSE: 0.002329
# Epoch 120 | Train MSE: 0.001996 | Val MSE: 0.002361
# Epoch 130 | Train MSE: 0.001839 | Val MSE: 0.002130
# Epoch 140 | Train MSE: 0.001804 | Val MSE: 0.002249
# Epoch 150 | Train MSE: 0.001701 | Val MSE: 0.002150
# Epoch 160 | Train MSE: 0.001745 | Val MSE: 0.002131
# Epoch 170 | Train MSE: 0.001575 | Val MSE: 0.002102
# Epoch 180 | Train MSE: 0.001621 | Val MSE: 0.002112
# Epoch 190 | Train MSE: 0.001519 | Val MSE: 0.002002
# Epoch 200 | Train MSE: 0.001499 | Val MSE: 0.002009
# Epoch 210 | Train MSE: 0.001475 | Val MSE: 0.001972
# Epoch 220 | Train MSE: 0.001447 | Val MSE: 0.001927
# Epoch 230 | Train MSE: 0.001503 | Val MSE: 0.001951
# Epoch 240 | Train MSE: 0.001367 | Val MSE: 0.001960
# Epoch 250 | Train MSE: 0.001380 | Val MSE: 0.001946
# Epoch 260 | Train MSE: 0.001348 | Val MSE: 0.001930
# Epoch 270 | Train MSE: 0.001304 | Val MSE: 0.001887
# Epoch 280 | Train MSE: 0.001270 | Val MSE: 0.001938
# Epoch 290 | Train MSE: 0.001306 | Val MSE: 0.001890
# Epoch 300 | Train MSE: 0.001281 | Val MSE: 0.001927
# Epoch 310 | Train MSE: 0.001229 | Val MSE: 0.001975
# Epoch 320 | Train MSE: 0.001184 | Val MSE: 0.001922
# Epoch 330 | Train MSE: 0.001235 | Val MSE: 0.001939
# Epoch 340 | Train MSE: 0.001180 | Val MSE: 0.001866
# Epoch 350 | Train MSE: 0.001127 | Val MSE: 0.001909
# Epoch 360 | Train MSE: 0.001142 | Val MSE: 0.001941
# Epoch 370 | Train MSE: 0.001139 | Val MSE: 0.001853
# Epoch 380 | Train MSE: 0.001176 | Val MSE: 0.001832
# Epoch 390 | Train MSE: 0.001085 | Val MSE: 0.001795
# Epoch 400 | Train MSE: 0.001100 | Val MSE: 0.001885
# Epoch 410 | Train MSE: 0.001067 | Val MSE: 0.001826
# Epoch 420 | Train MSE: 0.001027 | Val MSE: 0.001756
# Epoch 430 | Train MSE: 0.001022 | Val MSE: 0.001894
# Epoch 440 | Train MSE: 0.001047 | Val MSE: 0.001742
# Epoch 450 | Train MSE: 0.000995 | Val MSE: 0.001855
# Epoch 460 | Train MSE: 0.001024 | Val MSE: 0.001827
# Epoch 470 | Train MSE: 0.001013 | Val MSE: 0.001828
# Epoch 480 | Train MSE: 0.000999 | Val MSE: 0.001772
# Epoch 490 | Train MSE: 0.000968 | Val MSE: 0.001775
# Epoch 500 | Train MSE: 0.000970 | Val MSE: 0.001745
# Fold 8 - Train RMSE: 0.030750 | Val RMSE: 0.041774 | Test RMSE: 0.049724
#
# === Fold 9/10 ===
# Epoch 1 | Train MSE: 0.016464 | Val MSE: 0.014430
# Epoch 10 | Train MSE: 0.005947 | Val MSE: 0.005375
# Epoch 20 | Train MSE: 0.004136 | Val MSE: 0.003940
# Epoch 30 | Train MSE: 0.003504 | Val MSE: 0.003277
# Epoch 40 | Train MSE: 0.002935 | Val MSE: 0.002950
# Epoch 50 | Train MSE: 0.002691 | Val MSE: 0.002577
# Epoch 60 | Train MSE: 0.002416 | Val MSE: 0.002687
# Epoch 70 | Train MSE: 0.002270 | Val MSE: 0.002455
# Epoch 80 | Train MSE: 0.002194 | Val MSE: 0.002292
# Epoch 90 | Train MSE: 0.002130 | Val MSE: 0.002290
# Epoch 100 | Train MSE: 0.002017 | Val MSE: 0.002268
# Epoch 110 | Train MSE: 0.001998 | Val MSE: 0.002177
# Epoch 120 | Train MSE: 0.001863 | Val MSE: 0.002195
# Epoch 130 | Train MSE: 0.001744 | Val MSE: 0.002225
# Epoch 140 | Train MSE: 0.001773 | Val MSE: 0.002120
# Epoch 150 | Train MSE: 0.001635 | Val MSE: 0.002050
# Epoch 160 | Train MSE: 0.001618 | Val MSE: 0.002005
# Epoch 170 | Train MSE: 0.001609 | Val MSE: 0.001951
# Epoch 180 | Train MSE: 0.001534 | Val MSE: 0.001946
# Epoch 190 | Train MSE: 0.001488 | Val MSE: 0.001915
# Epoch 200 | Train MSE: 0.001462 | Val MSE: 0.002010
# Epoch 210 | Train MSE: 0.001389 | Val MSE: 0.001738
# Epoch 220 | Train MSE: 0.001424 | Val MSE: 0.001826
# Epoch 230 | Train MSE: 0.001335 | Val MSE: 0.001809
# Epoch 240 | Train MSE: 0.001315 | Val MSE: 0.001876
# Epoch 250 | Train MSE: 0.001310 | Val MSE: 0.001893
# Epoch 260 | Train MSE: 0.001306 | Val MSE: 0.001797
# Epoch 270 | Train MSE: 0.001263 | Val MSE: 0.001662
# Epoch 280 | Train MSE: 0.001236 | Val MSE: 0.001733
# Epoch 290 | Train MSE: 0.001220 | Val MSE: 0.001917
# Epoch 300 | Train MSE: 0.001187 | Val MSE: 0.001675
# Epoch 310 | Train MSE: 0.001135 | Val MSE: 0.001637
# Epoch 320 | Train MSE: 0.001161 | Val MSE: 0.001575
# Epoch 330 | Train MSE: 0.001095 | Val MSE: 0.001678
# Epoch 340 | Train MSE: 0.001106 | Val MSE: 0.001647
# Epoch 350 | Train MSE: 0.001081 | Val MSE: 0.001758
# Epoch 360 | Train MSE: 0.001049 | Val MSE: 0.001615
# Epoch 370 | Train MSE: 0.001076 | Val MSE: 0.001741
# Epoch 380 | Train MSE: 0.001011 | Val MSE: 0.001670
# Epoch 390 | Train MSE: 0.001029 | Val MSE: 0.001678
# Epoch 400 | Train MSE: 0.001056 | Val MSE: 0.001565
# Epoch 410 | Train MSE: 0.000977 | Val MSE: 0.001585
# Epoch 420 | Train MSE: 0.000983 | Val MSE: 0.001677
# Epoch 430 | Train MSE: 0.000962 | Val MSE: 0.001540
# Epoch 440 | Train MSE: 0.000952 | Val MSE: 0.001726
# Epoch 450 | Train MSE: 0.000913 | Val MSE: 0.001722
# Epoch 460 | Train MSE: 0.000907 | Val MSE: 0.001620
# Epoch 470 | Train MSE: 0.000960 | Val MSE: 0.001647
# Epoch 480 | Train MSE: 0.000920 | Val MSE: 0.001566
# Epoch 490 | Train MSE: 0.000913 | Val MSE: 0.001696
# Early stopping at epoch 492
# Fold 9 - Train RMSE: 0.029940 | Val RMSE: 0.040202 | Test RMSE: 0.047888
#
# === Fold 10/10 ===
# Epoch 1 | Train MSE: 0.017048 | Val MSE: 0.016058
# Epoch 10 | Train MSE: 0.005551 | Val MSE: 0.006325
# Epoch 20 | Train MSE: 0.004336 | Val MSE: 0.004507
# Epoch 30 | Train MSE: 0.003741 | Val MSE: 0.003943
# Epoch 40 | Train MSE: 0.003259 | Val MSE: 0.003366
# Epoch 50 | Train MSE: 0.002901 | Val MSE: 0.003261
# Epoch 60 | Train MSE: 0.002595 | Val MSE: 0.002899
# Epoch 70 | Train MSE: 0.002471 | Val MSE: 0.002669
# Epoch 80 | Train MSE: 0.002318 | Val MSE: 0.003413
# Epoch 90 | Train MSE: 0.002305 | Val MSE: 0.002512
# Epoch 100 | Train MSE: 0.002147 | Val MSE: 0.002417
# Epoch 110 | Train MSE: 0.002063 | Val MSE: 0.002397
# Epoch 120 | Train MSE: 0.001956 | Val MSE: 0.002208
# Epoch 130 | Train MSE: 0.001915 | Val MSE: 0.002245
# Epoch 140 | Train MSE: 0.001896 | Val MSE: 0.002194
# Epoch 150 | Train MSE: 0.001795 | Val MSE: 0.002317
# Epoch 160 | Train MSE: 0.001708 | Val MSE: 0.002216
# Epoch 170 | Train MSE: 0.001704 | Val MSE: 0.002307
# Epoch 180 | Train MSE: 0.001633 | Val MSE: 0.002022
# Epoch 190 | Train MSE: 0.001598 | Val MSE: 0.002058
# Epoch 200 | Train MSE: 0.001548 | Val MSE: 0.001990
# Epoch 210 | Train MSE: 0.001548 | Val MSE: 0.002085
# Epoch 220 | Train MSE: 0.001501 | Val MSE: 0.001941
# Epoch 230 | Train MSE: 0.001549 | Val MSE: 0.002002
# Epoch 240 | Train MSE: 0.001498 | Val MSE: 0.001933
# Epoch 250 | Train MSE: 0.001422 | Val MSE: 0.001913
# Epoch 260 | Train MSE: 0.001423 | Val MSE: 0.001962
# Epoch 270 | Train MSE: 0.001407 | Val MSE: 0.001877
# Epoch 280 | Train MSE: 0.001361 | Val MSE: 0.001945
# Epoch 290 | Train MSE: 0.001337 | Val MSE: 0.001969
# Epoch 300 | Train MSE: 0.001341 | Val MSE: 0.001877
# Epoch 310 | Train MSE: 0.001303 | Val MSE: 0.001879
# Epoch 320 | Train MSE: 0.001326 | Val MSE: 0.001961
# Epoch 330 | Train MSE: 0.001271 | Val MSE: 0.001849
# Epoch 340 | Train MSE: 0.001231 | Val MSE: 0.001858
# Epoch 350 | Train MSE: 0.001218 | Val MSE: 0.001739
# Epoch 360 | Train MSE: 0.001202 | Val MSE: 0.001775
# Epoch 370 | Train MSE: 0.001232 | Val MSE: 0.001772
# Epoch 380 | Train MSE: 0.001181 | Val MSE: 0.001836
# Epoch 390 | Train MSE: 0.001212 | Val MSE: 0.001936
# Epoch 400 | Train MSE: 0.001194 | Val MSE: 0.001771
# Epoch 410 | Train MSE: 0.001220 | Val MSE: 0.001873
# Epoch 420 | Train MSE: 0.001138 | Val MSE: 0.001749
# Epoch 430 | Train MSE: 0.001112 | Val MSE: 0.001758
# Epoch 440 | Train MSE: 0.001111 | Val MSE: 0.001662
# Epoch 450 | Train MSE: 0.001131 | Val MSE: 0.001778
# Epoch 460 | Train MSE: 0.001093 | Val MSE: 0.001743
# Epoch 470 | Train MSE: 0.001085 | Val MSE: 0.001736
# Epoch 480 | Train MSE: 0.001036 | Val MSE: 0.001666
# Epoch 490 | Train MSE: 0.001070 | Val MSE: 0.001709
# Epoch 500 | Train MSE: 0.001017 | Val MSE: 0.001894
# Fold 10 - Train RMSE: 0.034427 | Val RMSE: 0.043524 | Test RMSE: 0.050790
#
# === Final Results (mean ± std over folds) ===
# Train RMSE: 0.030951 ± 0.001854
# Val   RMSE: 0.041271 ± 0.001777
# Test  RMSE: 0.048950 ± 0.001081

# %%
import matplotlib.pyplot as plt
import numpy as np

train_mse_all = np.array(train_mse_all)                     # (runs,)
val_mse_all = np.array(val_mse_all)                         # (runs,)
test_mse_per_output_all = np.array(test_mse_per_output_all) # (runs, output_dim)
test_mse_total_all = np.array(test_mse_total_all)           # (runs,)

# ============ MSE/RMSE & STD ============
train_mse_mean = train_mse_all.mean()
train_mse_std = train_mse_all.std()
val_mse_mean = val_mse_all.mean()
val_mse_std = val_mse_all.std()

train_rmse_all = np.sqrt(train_mse_all)
val_rmse_all = np.sqrt(val_mse_all)
test_rmse_all = np.sqrt(test_mse_total_all)

train_rmse_mean = train_rmse_all.mean()
train_rmse_std = train_rmse_all.std()
val_rmse_mean = val_rmse_all.mean()
val_rmse_std = val_rmse_all.std()
test_rmse_mean = test_rmse_all.mean()
test_rmse_std = test_rmse_all.std()

# ============ Print results ============
print("Final Results (mean ± std over runs):")
print(f"Train Total MSE: {train_mse_mean:.6f} ± {train_mse_std:.6f} | RMSE: {train_rmse_mean:.6f} ± {train_rmse_std:.6f}")
print(f"Validation Total MSE: {val_mse_mean:.6f} ± {val_mse_std:.6f} | RMSE: {val_rmse_mean:.6f} ± {val_rmse_std:.6f}")
print(f"Test Total MSE: {test_mse_total_all.mean():.6f} ± {test_mse_total_all.std():.6f} | RMSE: {test_rmse_mean:.6f} ± {test_rmse_std:.6f}")

output_dim = test_mse_per_output_all.shape[1]

for i in range(output_dim):
    print(f"Test Output {i+1} MSE: {test_mse_per_output_all[:, i].mean():.6f} ± {test_mse_per_output_all[:, i].std():.6f}")

test_rmse_per_output_all = np.sqrt(test_mse_per_output_all)
for i in range(output_dim):
    print(f"Test Output {i+1} RMSE: {test_rmse_per_output_all[:, i].mean():.6f} ± {test_rmse_per_output_all[:, i].std():.6f}")

# ============ plot results of the last fold ============
# last_train_losses, last_val_losses:
plt.figure(figsize=(6, 3))
plt.plot(last_train_losses, label='Train Loss')
plt.plot(last_val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Val Loss over Epochs (last run)')
plt.legend()
plt.tight_layout()
plt.show()

# predicted vs actual
plt.figure(figsize=(18, 5))
for i in range(output_dim):
    plt.subplot(1, output_dim, i + 1)
    plt.plot(y_true_test_final[:, i], label='Actual')
    plt.plot(y_pred_test_final[:, i], label='Predicted')
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title(f'Test Predicted vs Actual - Step {i+1}')
    plt.legend()
plt.tight_layout()
plt.show()

train_final_rmse = train_rmse_all.mean()
val_final_rmse = val_rmse_all.mean()
test_final_rmse = test_rmse_all.mean()

plt.figure(figsize=(7, 5))
plt.bar(['Train', 'Val', 'Test'],
        [train_final_rmse, val_final_rmse, test_final_rmse],
        yerr=[train_rmse_std, val_rmse_std, test_rmse_std],
        capsize=5, color=['cornflowerblue', 'mediumseagreen', 'tomato'])
plt.ylabel('RMSE')
plt.title('Overall RMSE (mean ± std) Comparison')
plt.tight_layout()
plt.show()

# RMSE across steps
rmse_means = test_rmse_per_output_all.mean(axis=0)
rmse_stds = test_rmse_per_output_all.std(axis=0)
steps = [f'Step {i+1}' for i in range(output_dim)]

plt.figure(figsize=(8, 5))
plt.bar(steps, rmse_means, yerr=rmse_stds, capsize=5, color='indianred')
plt.xlabel('Output Step')
plt.ylabel('RMSE')
plt.title('Test Set RMSE per Output Dimension (mean ± std)')
plt.tight_layout()
plt.show()
# Out:
# Final Results (mean ± std over runs):
# Train Total MSE: 0.000961 ± 0.000117 | RMSE: 0.030951 ± 0.001854
# Validation Total MSE: 0.001706 ± 0.000144 | RMSE: 0.041271 ± 0.001777
# Test Total MSE: 0.002397 ± 0.000106 | RMSE: 0.048950 ± 0.001081
# Test Output 1 MSE: 0.001007 ± 0.000072
# Test Output 2 MSE: 0.001761 ± 0.000104
# Test Output 3 MSE: 0.002256 ± 0.000085
# Test Output 4 MSE: 0.002714 ± 0.000150
# Test Output 5 MSE: 0.003114 ± 0.000178
# Test Output 6 MSE: 0.003532 ± 0.000240
# Test Output 1 RMSE: 0.031709 ± 0.001122
# Test Output 2 RMSE: 0.041941 ± 0.001233
# Test Output 3 RMSE: 0.047491 ± 0.000907
# Test Output 4 RMSE: 0.052078 ± 0.001446
# Test Output 5 RMSE: 0.055778 ± 0.001592
# Test Output 6 RMSE: 0.059401 ± 0.001989
